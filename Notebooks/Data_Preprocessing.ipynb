# %% [markdown]
# # Data Preprocessing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Cleaned_Dataset.csv')
df
# Out:
#      brand_name       os  screen_size   4g   5g  main_camera_mp  \
# 0         Honor  Android        22.93  yes   no            13.0
# 1         Honor  Android        22.93  yes  yes            13.0
# 2         Honor  Android        22.93  yes  yes            13.0
# 3         Honor  Android        22.93  yes  yes            13.0
# 4         Honor  Android        15.72  yes   no            13.0
# ...         ...      ...          ...  ...  ...             ...
# 3363      Apple      iOS        15.40  yes   no             8.0
# 3364       Asus  Android        15.24  yes   no            13.0
# 3365    Alcatel  Android        18.73  yes   no            13.0
# 3366    Alcatel  Android        18.73  yes   no            13.0
# 3367    Alcatel  Android        13.49  yes   no            13.0
#
#       selfie_camera_mp  int_memory  ram  battery  weight  release_year  \
# 0                  5.0        64.0  4.0   3020.0   146.0        2020.0
# 1                 16.0       128.0  4.0   4300.0   213.0        2020.0
# 2                  8.0       128.0  4.0   4200.0   213.0        2020.0
# 3                  8.0        64.0  4.0   6675.0   240.0        2020.0
# 4                  8.0        64.0  4.0   5000.0   185.0        2020.0
# ...                ...         ...  ...      ...     ...           ...
# 3363               7.0        64.0  4.0   3110.0   194.0        2019.0
# 3364               8.0       128.0  4.0   4000.0   200.0        2018.0
# 3365               5.0        32.0  4.0   4000.0   165.0        2020.0
# 3366               5.0        32.0  4.0   4000.0   160.0        2020.0
# 3367               5.0        16.0  4.0   4000.0   168.0        2020.0
#
#       days_used  new_price  used_price
# 0         127.0  111.62000    86.96000
# 1         325.0  249.39000   161.49000
# 2         162.0  359.47000   233.22875
# 3         345.0  278.93000   180.23000
# 4         293.0  140.87000   103.80000
# ...         ...        ...         ...
# 3363      208.0  523.51125   233.22875
# 3364      541.0  518.81450   233.22875
# 3365      201.0   92.65000    69.81000
# 3366      149.0  101.91500    76.07000
# 3367      176.0   72.24150    50.48000
#
# [3368 rows x 15 columns]

# %%
data = df.copy()
data
# Out:
#      brand_name       os  screen_size   4g   5g  main_camera_mp  \
# 0         Honor  Android        22.93  yes   no            13.0
# 1         Honor  Android        22.93  yes  yes            13.0
# 2         Honor  Android        22.93  yes  yes            13.0
# 3         Honor  Android        22.93  yes  yes            13.0
# 4         Honor  Android        15.72  yes   no            13.0
# ...         ...      ...          ...  ...  ...             ...
# 3363      Apple      iOS        15.40  yes   no             8.0
# 3364       Asus  Android        15.24  yes   no            13.0
# 3365    Alcatel  Android        18.73  yes   no            13.0
# 3366    Alcatel  Android        18.73  yes   no            13.0
# 3367    Alcatel  Android        13.49  yes   no            13.0
#
#       selfie_camera_mp  int_memory  ram  battery  weight  release_year  \
# 0                  5.0        64.0  4.0   3020.0   146.0        2020.0
# 1                 16.0       128.0  4.0   4300.0   213.0        2020.0
# 2                  8.0       128.0  4.0   4200.0   213.0        2020.0
# 3                  8.0        64.0  4.0   6675.0   240.0        2020.0
# 4                  8.0        64.0  4.0   5000.0   185.0        2020.0
# ...                ...         ...  ...      ...     ...           ...
# 3363               7.0        64.0  4.0   3110.0   194.0        2019.0
# 3364               8.0       128.0  4.0   4000.0   200.0        2018.0
# 3365               5.0        32.0  4.0   4000.0   165.0        2020.0
# 3366               5.0        32.0  4.0   4000.0   160.0        2020.0
# 3367               5.0        16.0  4.0   4000.0   168.0        2020.0
#
#       days_used  new_price  used_price
# 0         127.0  111.62000    86.96000
# 1         325.0  249.39000   161.49000
# 2         162.0  359.47000   233.22875
# 3         345.0  278.93000   180.23000
# 4         293.0  140.87000   103.80000
# ...         ...        ...         ...
# 3363      208.0  523.51125   233.22875
# 3364      541.0  518.81450   233.22875
# 3365      201.0   92.65000    69.81000
# 3366      149.0  101.91500    76.07000
# 3367      176.0   72.24150    50.48000
#
# [3368 rows x 15 columns]

# %%
numerical_cols = list(data.select_dtypes(include='number').columns)
categorical_cols = list(data.select_dtypes(include='object').columns)

print(f"Numerical Columns = {numerical_cols}\n\nCartegorical Columns = {categorical_cols}")
# Out:
# Numerical Columns = ['screen_size', 'main_camera_mp', 'selfie_camera_mp', 'int_memory', 'ram', 'battery', 'weight', 'release_year', 'days_used', 'new_price', 'used_price']
#
# Cartegorical Columns = ['brand_name', 'os', '4g', '5g']

# %%
plt.figure(figsize=(20, 16))
sns.set_style("dark")  
sns.set_palette("Set2")    

for indx, col in enumerate(numerical_cols):
    plt.subplot(3, 4, indx + 1)

    sns.histplot(data[col], kde=True, bins=20, color='crimson', alpha=0.9, edgecolor="black")

    plt.title(f"Distribution of {col}", fontsize=14, weight='bold')
    plt.xlabel(col, fontsize=12, weight='bold')
    plt.ylabel("Count", fontsize=12, weight='bold')
    plt.grid(alpha=0.5, linestyle='--', color='black')

plt.tight_layout()
plt.show()

# %%
for col in numerical_cols:
    print(f"Mean of |{col}| = {data[col].mean():.2f}\nStandard Deviation |{col}| = {data[col].std():.2f}")
    print("\n")
# Out:
# Mean of |screen_size| = 14.32
# Standard Deviation |screen_size| = 4.35
#
#
# Mean of |main_camera_mp| = 9.39
# Standard Deviation |main_camera_mp| = 4.62
#
#
# Mean of |selfie_camera_mp| = 5.61
# Standard Deviation |selfie_camera_mp| = 5.06
#
#
# Mean of |int_memory| = 42.18
# Standard Deviation |int_memory| = 37.35
#
#
# Mean of |ram| = 4.00
# Standard Deviation |ram| = 0.00
#
#
# Mean of |battery| = 2977.65
# Standard Deviation |battery| = 1250.89
#
#
# Mean of |weight| = 162.37
# Standard Deviation |weight| = 38.86
#
#
# Mean of |release_year| = 2015.78
# Standard Deviation |release_year| = 2.19
#
#
# Mean of |days_used| = 695.18
# Standard Deviation |days_used| = 236.19
#
#
# Mean of |new_price| = 216.62
# Standard Deviation |new_price| = 128.50
#
#
# Mean of |used_price| = 90.92
# Standard Deviation |used_price| = 61.13

# %% [markdown]
# # Scaling
# `Standard Scaler`

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
data1 = data.drop('used_price', axis=1)
numerical_cols1 = list(data1.select_dtypes(include='number').columns)

# %%
for col in numerical_cols1:
    mean1 = data1[col].mean()
    std1 = data1[col].std()

    print(f"Before Scaling --- Mean = {mean1:.2f} ---- Std = {std1:.2f}")
    
    data1[col] = scaler.fit_transform(data1[[col]])
    print(f"{col} column in scaled")
    mean2 = data1[col].mean()
    std2 = data1[col].std()

    print(f"After Scaling --- Mean = {mean2:.2f} ---- Std = {std2:.2f}\n")
# Out:
# Before Scaling --- Mean = 14.32 ---- Std = 4.35
# screen_size column in scaled
# After Scaling --- Mean = -0.00 ---- Std = 1.00
#
# Before Scaling --- Mean = 9.39 ---- Std = 4.62
# main_camera_mp column in scaled
# After Scaling --- Mean = -0.00 ---- Std = 1.00
#
# Before Scaling --- Mean = 5.61 ---- Std = 5.06
# selfie_camera_mp column in scaled
# After Scaling --- Mean = 0.00 ---- Std = 1.00
#
# Before Scaling --- Mean = 42.18 ---- Std = 37.35
# int_memory column in scaled
# After Scaling --- Mean = 0.00 ---- Std = 1.00
#
# Before Scaling --- Mean = 4.00 ---- Std = 0.00
# ram column in scaled
# After Scaling --- Mean = 0.00 ---- Std = 0.00
#
# Before Scaling --- Mean = 2977.65 ---- Std = 1250.89
# battery column in scaled
# After Scaling --- Mean = 0.00 ---- Std = 1.00
#
# Before Scaling --- Mean = 162.37 ---- Std = 38.86
# weight column in scaled
# After Scaling --- Mean = -0.00 ---- Std = 1.00
#
# Before Scaling --- Mean = 2015.78 ---- Std = 2.19
# release_year column in scaled
# After Scaling --- Mean = -0.00 ---- Std = 1.00
#
# Before Scaling --- Mean = 695.18 ---- Std = 236.19
# days_used column in scaled
# After Scaling --- Mean = -0.00 ---- Std = 1.00
#
# Before Scaling --- Mean = 216.62 ---- Std = 128.50
# new_price column in scaled
# After Scaling --- Mean = 0.00 ---- Std = 1.00

# %%
data1['Used_Price'] = data['used_price']

# %%
# After Scaling
numerical_cols2 = (data1.select_dtypes(include='number').columns)
plt.figure(figsize=(20, 16))
sns.set_style("dark")  
sns.set_palette("Set2")    

for indx, col in enumerate(numerical_cols2):
    plt.subplot(3, 4, indx + 1)

    sns.histplot(data1[col], kde=True, bins=20, color='green', alpha=0.8, edgecolor="black")

    plt.title(f"Distribution of {col}", fontsize=14, weight='bold')
    plt.xlabel(col, fontsize=12, weight='bold')
    plt.ylabel("Count", fontsize=12, weight='bold')
    plt.grid(alpha=0.5, linestyle='--', color='black')

plt.tight_layout()
plt.show()

# %%
data1
# Out:
#      brand_name       os  screen_size   4g   5g  main_camera_mp  \
# 0         Honor  Android     1.978301  yes   no        0.781651
# 1         Honor  Android     1.978301  yes  yes        0.781651
# 2         Honor  Android     1.978301  yes  yes        0.781651
# 3         Honor  Android     1.978301  yes  yes        0.781651
# 4         Honor  Android     0.321578  yes   no        0.781651
# ...         ...      ...          ...  ...  ...             ...
# 3363      Apple      iOS     0.248048  yes   no       -0.300204
# 3364       Asus  Android     0.211283  yes   no        0.781651
# 3365    Alcatel  Android     1.013220  yes   no        0.781651
# 3366    Alcatel  Android     1.013220  yes   no        0.781651
# 3367    Alcatel  Android    -0.190834  yes   no        0.781651
#
#       selfie_camera_mp  int_memory  ram   battery    weight  release_year  \
# 0            -0.119840    0.584311  0.0  0.033857 -0.421187      1.930266
# 1             2.054621    2.298155  0.0  1.057278  1.303062      1.930266
# 2             0.473195    2.298155  0.0  0.977324  1.303062      1.930266
# 3             0.473195    0.584311  0.0  2.956205  1.997909      1.930266
# 4             0.473195    0.584311  0.0  1.616962  0.582481      1.930266
# ...                ...         ...  ...       ...       ...           ...
# 3363          0.275517    0.584311  0.0  0.105816  0.814096      1.473277
# 3364          0.473195    2.298155  0.0  0.817414  0.968507      1.016287
# 3365         -0.119840   -0.272611  0.0  0.817414  0.067780      1.930266
# 3366         -0.119840   -0.272611  0.0  0.817414 -0.060896      1.930266
# 3367         -0.119840   -0.701072  0.0  0.817414  0.144985      1.930266
#
#       days_used  new_price  Used_Price
# 0     -2.405987  -0.817247    86.96000
# 1     -1.567541   0.255023   161.49000
# 2     -2.257777   1.111781   233.22875
# 3     -1.482850   0.484934   180.23000
# 4     -1.703048  -0.589593   103.80000
# ...         ...        ...         ...
# 3363  -2.062986   2.388522   233.22875
# 3364  -0.652874   2.351967   233.22875
# 3365  -2.092628  -0.964892    69.81000
# 3366  -2.312826  -0.892782    76.07000
# 3367  -2.198493  -1.123732    50.48000
#
# [3368 rows x 15 columns]

# %% [markdown]
# # Data Encoding
# `Label Encoder`

# %%
categorical_cols
# Out:
# ['brand_name', 'os', '4g', '5g']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
for col in categorical_cols:
    data1[col] = encoder.fit_transform(data1[col])
    print(f"{col} column label encoding done.")
# Out:
# brand_name column label encoding done.
# os column label encoding done.
# 4g column label encoding done.
# 5g column label encoding done.

# %%
data1
# Out:
#       brand_name  os  screen_size  4g  5g  main_camera_mp  selfie_camera_mp  \
# 0             10   0     1.978301   1   0        0.781651         -0.119840
# 1             10   0     1.978301   1   1        0.781651          2.054621
# 2             10   0     1.978301   1   1        0.781651          0.473195
# 3             10   0     1.978301   1   1        0.781651          0.473195
# 4             10   0     0.321578   1   0        0.781651          0.473195
# ...          ...  ..          ...  ..  ..             ...               ...
# 3363           2   3     0.248048   1   0       -0.300204          0.275517
# 3364           3   0     0.211283   1   0        0.781651          0.473195
# 3365           1   0     1.013220   1   0        0.781651         -0.119840
# 3366           1   0     1.013220   1   0        0.781651         -0.119840
# 3367           1   0    -0.190834   1   0        0.781651         -0.119840
#
#       int_memory  ram   battery    weight  release_year  days_used  new_price  \
# 0       0.584311  0.0  0.033857 -0.421187      1.930266  -2.405987  -0.817247
# 1       2.298155  0.0  1.057278  1.303062      1.930266  -1.567541   0.255023
# 2       2.298155  0.0  0.977324  1.303062      1.930266  -2.257777   1.111781
# 3       0.584311  0.0  2.956205  1.997909      1.930266  -1.482850   0.484934
# 4       0.584311  0.0  1.616962  0.582481      1.930266  -1.703048  -0.589593
# ...          ...  ...       ...       ...           ...        ...        ...
# 3363    0.584311  0.0  0.105816  0.814096      1.473277  -2.062986   2.388522
# 3364    2.298155  0.0  0.817414  0.968507      1.016287  -0.652874   2.351967
# 3365   -0.272611  0.0  0.817414  0.067780      1.930266  -2.092628  -0.964892
# 3366   -0.272611  0.0  0.817414 -0.060896      1.930266  -2.312826  -0.892782
# 3367   -0.701072  0.0  0.817414  0.144985      1.930266  -2.198493  -1.123732
#
#       Used_Price
# 0       86.96000
# 1      161.49000
# 2      233.22875
# 3      180.23000
# 4      103.80000
# ...          ...
# 3363   233.22875
# 3364   233.22875
# 3365    69.81000
# 3366    76.07000
# 3367    50.48000
#
# [3368 rows x 15 columns]

# %%
data1.to_csv("Processed_Dataset.csv", index=False)
print("Data Processing done, saved as -> Processed_Dataset.csv")
# Out:
# Data Processing done, saved as -> Processed_Dataset.csv
